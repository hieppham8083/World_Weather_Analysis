# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 731

# %%
#Import dependencies
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# ing Record 34 of Set 6 | dingle
# Processing Record 35 of Set 6 | itarema
# Processing Record 36 of Set 6 | zhigansk
# Processing Record 37 of Set 6 | keokuk
# Processing Record 38 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 6 | savigliano
# Processing Record 40 of Set 6 | mishelevka
# Processing Record 41 of Set 6 | dwarka
# Processing Record 42 of Set 6 | faanui
# Processing Record 43 of Set 6 | luanda
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | ballina
# Processing Record 47 of Set 6 | palmas
# Processing Record 48 of Set 6 | sao gabriel da cachoeira
# Processing Record 49 of Set 6 | qui nhon
# Processing Record 50 of Set 6 | waren
# Processing Record 1 of Set 7 | fallon
# Processing Record 2 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 7 | barrow
# Processing Record 4 of Set 7 | kachug
# Processing Record 5 of Set 7 | bireun
# Processing Record 6 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 7 | asyut
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | acapulco
# Processing Record 10 of Set 7 | adeje
# Processing Record 11 of Set 7 | torbay
# Processing Record 12 of Set 7 | pokhara
# Processing Record 13 of Set 7 | arraial do cabo
# Processing Record 14 of Set 7 | chabahar
# Processing Record 15 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 7 | boddam
# Processing Record 18 of Set 7 | lashio
# Processing Record 19 of Set 7 | puerto escondido
# Processing Record 20 of Set 7 | frederikshavn
# Processing Record 21 of Set 7 | liusha
# Processing Record 22 of Set 7 | whitehorse
# Processing Record 23 of Set 7 | bay roberts
# Processing Record 24 of Set 7 | tezu
# Processing Record 25 of Set 7 | san policarpo
# Processing Record 26 of Set 7 | surt
# Processing Record 27 of Set 7 | anadyr
# Processing Record 28 of Set 7 | vao
# Processing Record 29 of Set 7 | beni
# Processing Record 30 of Set 7 | uribia
# Processing Record 31 of Set 7 | sao joao da barra
# Processing Record 32 of Set 7 | pevek
# Processing Record 33 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 7 | wilmington
# Processing Record 35 of Set 7 | vallenar
# Processing Record 36 of Set 7 | boali
# Processing Record 37 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 7 | saint-georges
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | vardo
# Processing Record 41 of Set 7 | guerrero negro
# Processing Record 42 of Set 7 | esperance
# Processing Record 43 of Set 7 | tucumcari
# Processing Record 44 of Set 7 | vila
# Processing Record 45 of Set 7 | claremore
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | irbeyskoye
# Processing Record 49 of Set 7 | koumac
# Processing Record 50 of Set 7 | dalbandin
# Processing Record 1 of Set 8 | port augusta
# Processing Record 2 of Set 8 | xining
# Processing Record 3 of Set 8 | jamame
# Processing Record 4 of Set 8 | kingsteignton
# Processing Record 5 of Set 8 | yarensk
# Processing Record 6 of Set 8 | limbang
# Processing Record 7 of Set 8 | morris
# Processing Record 8 of Set 8 | mae hong son
# Processing Record 9 of Set 8 | yinchuan
# Processing Record 10 of Set 8 | haicheng
# Processing Record 11 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 12 of Set 8 | stykkisholmur
# Processing Record 13 of Set 8 | harper
# Processing Record 14 of Set 8 | pundaguitan
# Processing Record 15 of Set 8 | kumluca
# Processing Record 16 of Set 8 | mildura
# Processing Record 17 of Set 8 | alice springs
# Processing Record 18 of Set 8 | novyy yarychiv
# Processing Record 19 of Set 8 | mehamn
# Processing Record 20 of Set 8 | smithers
# Processing Record 21 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 22 of Set 8 | deputatskiy
# Processing Record 23 of Set 8 | alamosa
# Processing Record 24 of Set 8 | ballybofey
# Processing Record 25 of Set 8 | kendari
# Processing Record 26 of Set 8 | shipunovo
# Processing Record 27 of Set 8 | santa cruz
# Processing Record 28 of Set 8 | sal rei
# Processing Record 29 of Set 8 | tomatlan
# Processing Record 30 of Set 8 | sistranda
# Processing Record 31 of Set 8 | awbari
# Processing Record 32 of Set 8 | tigil
# Processing Record 33 of Set 8 | gouyave
# Processing Record 34 of Set 8 | padang
# Processing Record 35 of Set 8 | riyadh
# Processing Record 36 of Set 8 | ulaangom
# Processing Record 37 of Set 8 | nouadhibou
# Processing Record 38 of Set 8 | brownfield
# Processing Record 39 of Set 8 | boa vista
# Processing Record 40 of Set 8 | mount gambier
# Processing Record 41 of Set 8 | talnakh
# Processing Record 42 of Set 8 | nioro
# Processing Record 43 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 8 | isla vista
# Processing Record 46 of Set 8 | bagdarin
# Processing Record 47 of Set 8 | newport
# Processing Record 48 of Set 8 | san andres
# Processing Record 49 of Set 8 | rundu
# Processing Record 50 of Set 8 | teya
# Processing Record 1 of Set 9 | garm
# City not found. Skipping...
# Processing Record 2 of Set 9 | karaman
# Processing Record 3 of Set 9 | virginia beach
# Processing Record 4 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 9 | marawi
# Processing Record 6 of Set 9 | moranbah
# Processing Record 7 of Set 9 | erdenet
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | timra
# Processing Record 10 of Set 9 | campos belos
# Processing Record 11 of Set 9 | mackay
# Processing Record 12 of Set 9 | san rafael
# Processing Record 13 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 9 | chernyshevskiy
# Processing Record 15 of Set 9 | muswellbrook
# Processing Record 16 of Set 9 | roma
# Processing Record 17 of Set 9 | shu
# Processing Record 18 of Set 9 | sfantu gheorghe
# Processing Record 19 of Set 9 | provideniya
# Processing Record 20 of Set 9 | mecca
# Processing Record 21 of Set 9 | wanning
# Processing Record 22 of Set 9 | mayumba
# Processing Record 23 of Set 9 | tibati
# Processing Record 24 of Set 9 | havre-saint-pierre
# Processing Record 25 of Set 9 | sibut
# Processing Record 26 of Set 9 | lokosovo
# Processing Record 27 of Set 9 | coihaique
# Processing Record 28 of Set 9 | umm lajj
# Processing Record 29 of Set 9 | pasighat
# Processing Record 30 of Set 9 | raga
# Processing Record 31 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 9 | henties bay
# Processing Record 33 of Set 9 | yatou
# Processing Record 34 of Set 9 | vredendal
# Processing Record 35 of Set 9 | furukawa
# Processing Record 36 of Set 9 | mutoko
# Processing Record 37 of Set 9 | gizo
# Processing Record 38 of Set 9 | paytug
# City not found. Skipping...
# Processing Record 39 of Set 9 | san jose
# Processing Record 40 of Set 9 | lompoc
# Processing Record 41 of Set 9 | bongandanga
# Processing Record 42 of Set 9 | alyangula
# Processing Record 43 of Set 9 | derzhavinsk
# Processing Record 44 of Set 9 | quang ngai
# Processing Record 45 of Set 9 | lethem
# Processing Record 46 of Set 9 | richards bay
# Processing Record 47 of Set 9 | remanso
# Processing Record 48 of Set 9 | naze
# Processing Record 49 of Set 9 | khandyga
# Processing Record 50 of Set 9 | hervey bay
# Processing Record 1 of Set 10 | kieta
# Processing Record 2 of Set 10 | barpathar
# Processing Record 3 of Set 10 | tukrah
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | shcholkine
# City not found. Skipping...
# Processing Record 6 of Set 10 | ilo
# Processing Record 7 of Set 10 | tiszanana
# Processing Record 8 of Set 10 | alindao
# Processing Record 9 of Set 10 | pontalina
# Processing Record 10 of Set 10 | mananjary
# Processing Record 11 of Set 10 | palimbang
# Processing Record 12 of Set 10 | beberibe
# Processing Record 13 of Set 10 | grindavik
# Processing Record 14 of Set 10 | tiznit
# Processing Record 15 of Set 10 | high level
# Processing Record 16 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 17 of Set 10 | namatanai
# Processing Record 18 of Set 10 | tabora
# Processing Record 19 of Set 10 | whitehaven
# Processing Record 20 of Set 10 | codrington
# Processing Record 21 of Set 10 | pacific grove
# Processing Record 22 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 23 of Set 10 | gaborone
# Processing Record 24 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 10 | san felipe
# Processing Record 26 of Set 10 | esik
# Processing Record 27 of Set 10 | mallama
# City not found. Skipping...
# Processing Record 28 of Set 10 | hokitika
# Processing Record 29 of Set 10 | sakakah
# Processing Record 30 of Set 10 | praia da vitoria
# Processing Record 31 of Set 10 | port-gentil
# Processing Record 32 of Set 10 | alta floresta
# Processing Record 33 of Set 10 | port keats
# Processing Record 34 of Set 10 | los llanos de aridane
# Processing Record 35 of Set 10 | tiksi
# Processing Record 36 of Set 10 | marathopolis
# City not found. Skipping...
# Processing Record 37 of Set 10 | carutapera
# Processing Record 38 of Set 10 | saint anthony
# Processing Record 39 of Set 10 | shubarshi
# Processing Record 40 of Set 10 | tetouan
# Processing Record 41 of Set 10 | manzanillo
# Processing Record 42 of Set 10 | vuktyl
# Processing Record 43 of Set 10 | pandan
# Processing Record 44 of Set 10 | trapani
# Processing Record 45 of Set 10 | simbahan
# Processing Record 46 of Set 10 | karratha
# Processing Record 47 of Set 10 | dawlatabad
# Processing Record 48 of Set 10 | atbasar
# Processing Record 49 of Set 10 | tam ky
# Processing Record 50 of Set 10 | mingguang
# Processing Record 1 of Set 11 | tubuala
# Processing Record 2 of Set 11 | kabarnet
# Processing Record 3 of Set 11 | kysyl-syr
# Processing Record 4 of Set 11 | mongomo
# Processing Record 5 of Set 11 | upington
# Processing Record 6 of Set 11 | ambilobe
# Processing Record 7 of Set 11 | mbacke
# City not found. Skipping...
# Processing Record 8 of Set 11 | dunedin
# Processing Record 9 of Set 11 | pesochnoye
# Processing Record 10 of Set 11 | san luis
# Processing Record 11 of Set 11 | souillac
# Processing Record 12 of Set 11 | sovetskaya gavan
# Processing Record 13 of Set 11 | ambovombe
# Processing Record 14 of Set 11 | santo angelo
# Processing Record 15 of Set 11 | santa marta
# Processing Record 16 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 17 of Set 11 | jiazi
# Processing Record 18 of Set 11 | nizwa
# Processing Record 19 of Set 11 | waitati
# Processing Record 20 of Set 11 | urengoy
# Processing Record 21 of Set 11 | ankazoabo
# Processing Record 22 of Set 11 | ostrovnoy
# Processing Record 23 of Set 11 | baykit
# Processing Record 24 of Set 11 | kariba
# Processing Record 25 of Set 11 | basco
# Processing Record 26 of Set 11 | mancio lima
# Processing Record 27 of Set 11 | burica
# City not found. Skipping...
# Processing Record 28 of Set 11 | hammond
# Processing Record 29 of Set 11 | registro
# Processing Record 30 of Set 11 | chicama
# Processing Record 31 of Set 11 | puerto madryn
# Processing Record 32 of Set 11 | verkhnyaya inta
# Processing Record 33 of Set 11 | panzhihua
# Processing Record 34 of Set 11 | vostok
# Processing Record 35 of Set 11 | chapais
# Processing Record 36 of Set 11 | baiyin
# Processing Record 37 of Set 11 | mirnyy
# Processing Record 38 of Set 11 | severnoye
# Processing Record 39 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 11 | barcelona
# Processing Record 41 of Set 11 | consolacion del sur
# Processing Record 42 of Set 11 | jieshi
# Processing Record 43 of Set 11 | gusev
# Processing Record 44 of Set 11 | paraiso
# Processing Record 45 of Set 11 | stephenville
# Processing Record 46 of Set 11 | gladstone
# Processing Record 47 of Set 11 | mehran
# Processing Record 48 of Set 11 | walvis bay
# Processing Record 49 of Set 11 | ketou
# Processing Record 50 of Set 11 | waipawa
# Processing Record 1 of Set 12 | santa comba
# Processing Record 2 of Set 12 | sindor
# Processing Record 3 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 4 of Set 12 | san cristobal
# Processing Record 5 of Set 12 | madarounfa
# Processing Record 6 of Set 12 | okmulgee
# Processing Record 7 of Set 12 | vestmannaeyjar
# Processing Record 8 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 12 | nador
# Processing Record 10 of Set 12 | ursulo galvan
# Processing Record 11 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 12 | cutro
# Processing Record 13 of Set 12 | trairi
# Processing Record 14 of Set 12 | dobrinka
# Processing Record 15 of Set 12 | jumla
# Processing Record 16 of Set 12 | dustlik
# Processing Record 17 of Set 12 | hay river
# Processing Record 18 of Set 12 | killybegs
# Processing Record 19 of Set 12 | lillooet
# Processing Record 20 of Set 12 | lodwar
# Processing Record 21 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 12 | skibbereen
# Processing Record 23 of Set 12 | atherton
# Processing Record 24 of Set 12 | la rioja
# Processing Record 25 of Set 12 | brzeziny
# Processing Record 26 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 12 | jaisalmer
# Processing Record 28 of Set 12 | balaytigui
# City not found. Skipping...
# Processing Record 29 of Set 12 | lasa
# Processing Record 30 of Set 12 | griffith
# Processing Record 31 of Set 12 | mizdah
# Processing Record 32 of Set 12 | karlskrona
# Processing Record 33 of Set 12 | yakuplu
# Processing Record 34 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 12 | san isidro
# Processing Record 37 of Set 12 | kankon
# Processing Record 38 of Set 12 | plouzane
# Processing Record 39 of Set 12 | smidovich
# Processing Record 40 of Set 12 | coahuayana
# Processing Record 41 of Set 12 | luderitz
# Processing Record 42 of Set 12 | hanmer springs
# Processing Record 43 of Set 12 | kupang
# Processing Record 44 of Set 12 | aklavik
# Processing Record 45 of Set 12 | parkes
# Processing Record 46 of Set 12 | poitiers
# Processing Record 47 of Set 12 | tarrega
# Processing Record 48 of Set 12 | bo rai
# Processing Record 49 of Set 12 | klyuchi
# Processing Record 50 of Set 12 | fairbanks
# Processing Record 1 of Set 13 | batagay
# Processing Record 2 of Set 13 | nacala
# Processing Record 3 of Set 13 | iskateley
# Processing Record 4 of Set 13 | tilichiki
# Processing Record 5 of Set 13 | jizan
# Processing Record 6 of Set 13 | road town
# Processing Record 7 of Set 13 | hit
# Processing Record 8 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 10 of Set 13 | te anau
# Processing Record 11 of Set 13 | ketchikan
# Processing Record 12 of Set 13 | bissora
# Processing Record 13 of Set 13 | kant
# Processing Record 14 of Set 13 | nara
# Processing Record 15 of Set 13 | havelock
# Processing Record 16 of Set 13 | akyab
# Processing Record 17 of Set 13 | palmer
# Processing Record 18 of Set 13 | bathurst
# Processing Record 19 of Set 13 | montecristi
# Processing Record 20 of Set 13 | koygorodok
# Processing Record 21 of Set 13 | amapa
# Processing Record 22 of Set 13 | komsomolskiy
# Processing Record 23 of Set 13 | algiers
# Processing Record 24 of Set 13 | sinjar
# Processing Record 25 of Set 13 | bull savanna
# Processing Record 26 of Set 13 | qaqortoq
# Processing Record 27 of Set 13 | odweyne
# Processing Record 28 of Set 13 | kuliyapitiya
# Processing Record 29 of Set 13 | eydhafushi
# Processing Record 30 of Set 13 | lata
# Processing Record 31 of Set 13 | baleno
# Processing Record 32 of Set 13 | harlingen
# Processing Record 33 of Set 13 | miramar
# Processing Record 34 of Set 13 | volgorechensk
# Processing Record 35 of Set 13 | the valley
# Processing Record 36 of Set 13 | ati
# Processing Record 37 of Set 13 | mayo
# Processing Record 38 of Set 13 | sinnamary
# Processing Record 39 of Set 13 | wajir
# Processing Record 40 of Set 13 | souris
# Processing Record 41 of Set 13 | tabou
# Processing Record 42 of Set 13 | zalantun
# Processing Record 43 of Set 13 | weligama
# Processing Record 44 of Set 13 | sidi ali
# Processing Record 45 of Set 13 | brusyliv
# Processing Record 46 of Set 13 | canberra
# Processing Record 47 of Set 13 | bela vista
# Processing Record 48 of Set 13 | chiang klang
# Processing Record 49 of Set 13 | adra
# Processing Record 50 of Set 13 | yarmouth
# Processing Record 1 of Set 14 | hovd
# Processing Record 2 of Set 14 | axim
# Processing Record 3 of Set 14 | shanghai
# Processing Record 4 of Set 14 | duobao
# Processing Record 5 of Set 14 | haukipudas
# Processing Record 6 of Set 14 | grand-santi
# Processing Record 7 of Set 14 | northam
# Processing Record 8 of Set 14 | huarmey
# Processing Record 9 of Set 14 | vazante
# Processing Record 10 of Set 14 | bara
# Processing Record 11 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 12 of Set 14 | mareeba
# Processing Record 13 of Set 14 | raahe
# Processing Record 14 of Set 14 | gewane
# Processing Record 15 of Set 14 | kollam
# Processing Record 16 of Set 14 | magadan
# Processing Record 17 of Set 14 | noumea
# Processing Record 18 of Set 14 | omidiyeh
# Processing Record 19 of Set 14 | puerto del rosario
# Processing Record 20 of Set 14 | nyurba
# Processing Record 21 of Set 14 | mahdalynivka
# Processing Record 22 of Set 14 | ipixuna
# Processing Record 23 of Set 14 | cay
# Processing Record 24 of Set 14 | tandalti
# Processing Record 25 of Set 14 | astipalaia
# City not found. Skipping...
# Processing Record 26 of Set 14 | pravia
# Processing Record 27 of Set 14 | araouane
# Processing Record 28 of Set 14 | boende
# Processing Record 29 of Set 14 | inhambane
# Processing Record 30 of Set 14 | ancud
# Processing Record 31 of Set 14 | sijunjung
# Processing Record 32 of Set 14 | golpayegan
# Processing Record 33 of Set 14 | miraflores
# Processing Record 34 of Set 14 | pangkalanbuun
# Processing Record 35 of Set 14 | micheweni
# Processing Record 36 of Set 14 | dubai
# Processing Record 37 of Set 14 | salima
# Processing Record 38 of Set 14 | kozmodemyansk
# Processing Record 39 of Set 14 | cap malheureux
# Processing Record 40 of Set 14 | formosa
# Processing Record 41 of Set 14 | mikhaylovka
# Processing Record 42 of Set 14 | rovnoye
# Processing Record 43 of Set 14 | turukhansk
# Processing Record 44 of Set 14 | sorong
# Processing Record 45 of Set 14 | adrar
# Processing Record 46 of Set 14 | robe
# Processing Record 47 of Set 14 | nouakchott
# Processing Record 48 of Set 14 | kamaishi
# Processing Record 49 of Set 14 | san patricio
# Processing Record 50 of Set 14 | pangoa
# Processing Record 1 of Set 15 | les escoumins
# Processing Record 2 of Set 15 | nagireddipalle
# City not found. Skipping...
# Processing Record 3 of Set 15 | vestmanna
# Processing Record 4 of Set 15 | valdemarpils
# Processing Record 5 of Set 15 | dilijan
# Processing Record 6 of Set 15 | svetlaya
# Processing Record 7 of Set 15 | nuuk
# Processing Record 8 of Set 15 | kristianstad
# Processing Record 9 of Set 15 | katha
# City not found. Skipping...
# Processing Record 10 of Set 15 | brae
# Processing Record 11 of Set 15 | charlestown
# Processing Record 12 of Set 15 | jasper
# Processing Record 13 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 14 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 15 | zhezkazgan
# Processing Record 16 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 15 | paita
# Processing Record 18 of Set 15 | banda aceh
# Processing Record 19 of Set 15 | isoka
# Processing Record 20 of Set 15 | nelson bay
# Processing Record 21 of Set 15 | viedma
# Processing Record 22 of Set 15 | tura
# Processing Record 23 of Set 15 | mogadishu
# Processing Record 24 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 15 | sungaipenuh
# Processing Record 26 of Set 15 | ozoir-la-ferriere
# Processing Record 27 of Set 15 | itoman
# Processing Record 28 of Set 15 | barra patuca
# Processing Record 29 of Set 15 | alekseyevskaya
# Processing Record 30 of Set 15 | sao sebastiao
# Processing Record 31 of Set 15 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 662

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sierra Vista      US  31.5545 -110.3037     48.20        18           1
# 1     Ilulissat      GL  69.2167  -51.1000      8.60        56          40
# 2        Wajima      JP  37.4000  136.9000     26.60       100          90
# 3       Salalah      OM  17.0151   54.0924     77.94        27           0
# 4    Nikolskoye      RU  59.7035   30.7861     12.00        85           0
#
#    Wind Speed Current Description
# 0       10.36           clear sky
# 1       23.02          light snow
# 2        2.30                snow
# 3        9.53           clear sky
# 4        4.47           clear sky

# %%
data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(data_file, index_label='City_ID')
